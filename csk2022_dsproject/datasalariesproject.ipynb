# %%
#setup 

import numpy as np
import pandas as pd
import ipywidgets as widgets
import matplotlib.pyplot as plt
import sklearn 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import seaborn

df = pd.read_csv('C:/Users/chloe/OneDrive/Desktop/ds_salaries.csv')
df.dropna(inplace=True)
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
#reading in data

work_years = df.work_year.unique()
experience_levels = df.experience_level.unique()
employment_types = df.employment_type.unique()
job_titles = sorted(df.job_title.unique())
remote_ratios = df.remote_ratio.unique()
salary_currencies = df.salary_currency.unique()
employee_residences = df.employee_residence.unique()
company_locations = df.company_location.unique()
company_sizes = df.company_size.unique()

print("Work Years:", work_years)
print("Experience Levels:", experience_levels)
print("Employment Types:", employment_types)
print("Salary Currencies:", salary_currencies)
print("Employee Residences:", employee_residences)
print("Company Locations:", company_locations)
print("Job Titles:", job_titles)
# Out:
# Work Years: [2020 2021 2022]
# Experience Levels: ['MI' 'SE' 'EN' 'EX']
# Employment Types: ['FT' 'CT' 'PT' 'FL']
# Salary Currencies: ['EUR' 'USD' 'GBP' 'HUF' 'INR' 'JPY' 'CNY' 'MXN' 'CAD' 'DKK' 'PLN' 'SGD'
#  'CLP' 'BRL' 'TRY' 'AUD' 'CHF']
# Employee Residences: ['DE' 'JP' 'GB' 'HN' 'US' 'HU' 'NZ' 'FR' 'IN' 'PK' 'PL' 'PT' 'CN' 'GR'
#  'AE' 'NL' 'MX' 'CA' 'AT' 'NG' 'PH' 'ES' 'DK' 'RU' 'IT' 'HR' 'BG' 'SG'
#  'BR' 'IQ' 'VN' 'BE' 'UA' 'MT' 'CL' 'RO' 'IR' 'CO' 'MD' 'KE' 'SI' 'HK'
#  'TR' 'RS' 'PR' 'LU' 'JE' 'CZ' 'AR' 'DZ' 'TN' 'MY' 'EE' 'AU' 'BO' 'IE'
#  'CH']
# Company Locations: ['DE' 'JP' 'GB' 'HN' 'US' 'HU' 'NZ' 'FR' 'IN' 'PK' 'CN' 'GR' 'AE' 'NL'
#  'MX' 'CA' 'AT' 'NG' 'ES' 'PT' 'DK' 'IT' 'HR' 'LU' 'PL' 'SG' 'RO' 'IQ'
#  'BR' 'BE' 'UA' 'IL' 'RU' 'MT' 'CL' 'IR' 'CO' 'MD' 'KE' 'SI' 'CH' 'VN'
#  'AS' 'TR' 'CZ' 'DZ' 'EE' 'MY' 'AU' 'IE']
# Job Titles: ['3D Computer Vision Researcher', 'AI Scientist', 'Analytics Engineer', 'Applied Data Scientist', 'Applied Machine Learning Scientist', 'BI Data Analyst', 'Big Data Architect', 'Big Data Engineer', 'Business Data Analyst', 'Cloud Data Engineer', 'Computer Vision Engineer', 'Computer Vision Software Engineer', 'Data Analyst', 'Data Analytics Engineer', 'Data Analytics Lead', 'Data Analytics Manager', 'Data Architect', 'Data Engineer', 'Data Engineering Manager', 'Data Science Consultant', 'Data Science Engineer', 'Data Science Manager', 'Data Scientist', 'Data Specialist', 'Director of Data Engineering', 'Director of Data Science', 'ETL Developer', 'Finance Data Analyst', 'Financial Data Analyst', 'Head of Data', 'Head of Data Science', 'Head of Machine Learning', 'Lead Data Analyst', 'Lead Data Engineer', 'Lead Data Scientist', 'Lead Machine Learning Engineer', 'ML Engineer', 'Machine Learning Developer', 'Machine Learning Engineer', 'Machine Learning Infrastructure Engineer', 'Machine Learning Manager', 'Machine Learning Scientist', 'Marketing Data Analyst', 'NLP Engineer', 'Principal Data Analyst', 'Principal Data Engineer', 'Principal Data Scientist', 'Product Data Analyst', 'Research Scientist', 'Staff Data Scientist']

# %%
#salary statistics

salaries = df.salary.values.tolist()
salaries_in_usd = df.salary_in_usd.tolist()
average = round(sum(salaries_in_usd)/len(salaries_in_usd),2)
print("The salaries (USD) range from " + str(min(salaries_in_usd)) + " USD to " + str(max(salaries_in_usd)) + " USD")
print("The average salary (USD) is: " + str(average) + " USD")
# Out:
# The salaries (USD) range from 2859 USD to 600000 USD
# The average salary (USD) is: 112297.87 USD

# %%
#salaries by job title

jobstats = {}
averages = []
maxes = []

#read in data
temp = df.groupby(['job_title'])
for x in range(len(job_titles)): 
    currentjob = job_titles[x]
    a = temp.get_group(currentjob)
    tempsalaries = a.salary_in_usd.values.tolist()
    tempavg = round(sum(tempsalaries)/len(tempsalaries),2)
    averages.append(tempavg)
    tempmin = min(tempsalaries)
    tempmax = max(tempsalaries)
    maxes.append(tempmax)
    temprange = tempmax - tempmin
    templist = [tempavg, tempmin, tempmax, temprange]
    jobstats[currentjob] = templist

#output data (by job title)
def stats_by_job():
    for key in jobstats: 
        print(key + ":")
        stats = jobstats[key]
        print("Average Salary: " + str(stats[0]) + " USD")
        print("Minimum Salary: " + str(stats[1]) + " USD")
        print("Maximum Salary: " + str(stats[2]) + " USD")
        print("Salary Range: " + str(stats[3]) + " USD")
        print("")

def plot_average():
    #average salary by job title 
    fig = plt.figure(figsize = (30,10))
    plt.bar(job_titles, averages, color = '#87bdd6', width = 0.7)
    plt.xlabel("Job Titles", fontsize = 20)
    plt.ylabel("Average Salaries", fontsize = 20)
    plt.title("Average Salary by Job Title", fontsize = 30)
    plt.xticks(rotation=90)
    plt.show

def plot_maximum():
    #maximum salary by job title 

    fig = plt.figure(figsize = (30,10))
    plt.bar(job_titles, maxes, color = '#b688cf', width = 0.7)
    plt.xlabel("Job Titles", fontsize = 20)
    plt.ylabel("Maximum Salaries", fontsize = 20)
    plt.title("Maximum Salary by Job Title", fontsize = 30)
    plt.xticks(rotation=90)
    plt.show

stats_by_job()
plot_average()
plot_maximum()
# Out:
# 3D Computer Vision Researcher:
# Average Salary: 5409.0 USD
# Minimum Salary: 5409 USD
# Maximum Salary: 5409 USD
# Salary Range: 0 USD
#
# AI Scientist:
# Average Salary: 66135.57 USD
# Minimum Salary: 12000 USD
# Maximum Salary: 200000 USD
# Salary Range: 188000 USD
#
# Analytics Engineer:
# Average Salary: 175000.0 USD
# Minimum Salary: 135000 USD
# Maximum Salary: 205300 USD
# Salary Range: 70300 USD
#
# Applied Data Scientist:
# Average Salary: 175655.0 USD
# Minimum Salary: 54238 USD
# Maximum Salary: 380000 USD
# Salary Range: 325762 USD
#
# Applied Machine Learning Scientist:
# Average Salary: 142068.75 USD
# Minimum Salary: 31875 USD
# Maximum Salary: 423000 USD
# Salary Range: 391125 USD
#
# BI Data Analyst:
# Average Salary: 74755.17 USD
# Minimum Salary: 9272 USD
# Maximum Salary: 150000 USD
# Salary Range: 140728 USD
#
# Big Data Architect:
# Average Salary: 99703.0 USD
# Minimum Salary: 99703 USD
# Maximum Salary: 99703 USD
# Salary Range: 0 USD
#
# Big Data Engineer:
# Average Salary: 51974.0 USD
# Minimum Salary: 5882 USD
# Maximum Salary: 114047 USD
# Salary Range: 108165 USD
#
# Business Data Analyst:
# Average Salary: 76691.2 USD
# Minimum Salary: 18442 USD
# Maximum Salary: 135000 USD
# Salary Range: 116558 USD
#
# Cloud Data Engineer:
# Average Salary: 124647.0 USD
# Minimum Salary: 89294 USD
# Maximum Salary: 160000 USD
# Salary Range: 70706 USD
#
# Computer Vision Engineer:
# Average Salary: 44419.33 USD
# Minimum Salary: 10000 USD
# Maximum Salary: 125000 USD
# Salary Range: 115000 USD
#
# Computer Vision Software Engineer:
# Average Salary: 105248.67 USD
# Minimum Salary: 70000 USD
# Maximum Salary: 150000 USD
# Salary Range: 80000 USD
#
# Data Analyst:
# Average Salary: 92893.06 USD
# Minimum Salary: 6072 USD
# Maximum Salary: 200000 USD
# Salary Range: 193928 USD
#
# Data Analytics Engineer:
# Average Salary: 64799.25 USD
# Minimum Salary: 20000 USD
# Maximum Salary: 110000 USD
# Salary Range: 90000 USD
#
# Data Analytics Lead:
# Average Salary: 405000.0 USD
# Minimum Salary: 405000 USD
# Maximum Salary: 405000 USD
# Salary Range: 0 USD
#
# Data Analytics Manager:
# Average Salary: 127134.29 USD
# Minimum Salary: 105400 USD
# Maximum Salary: 150260 USD
# Salary Range: 44860 USD
#
# Data Architect:
# Average Salary: 177873.91 USD
# Minimum Salary: 90700 USD
# Maximum Salary: 266400 USD
# Salary Range: 175700 USD
#
# Data Engineer:
# Average Salary: 112725.0 USD
# Minimum Salary: 4000 USD
# Maximum Salary: 324000 USD
# Salary Range: 320000 USD
#
# Data Engineering Manager:
# Average Salary: 123227.2 USD
# Minimum Salary: 59303 USD
# Maximum Salary: 174000 USD
# Salary Range: 114697 USD
#
# Data Science Consultant:
# Average Salary: 69420.71 USD
# Minimum Salary: 5707 USD
# Maximum Salary: 103000 USD
# Salary Range: 97293 USD
#
# Data Science Engineer:
# Average Salary: 75803.33 USD
# Minimum Salary: 40189 USD
# Maximum Salary: 127221 USD
# Salary Range: 87032 USD
#
# Data Science Manager:
# Average Salary: 158328.5 USD
# Minimum Salary: 54094 USD
# Maximum Salary: 241000 USD
# Salary Range: 186906 USD
#
# Data Scientist:
# Average Salary: 108187.83 USD
# Minimum Salary: 2859 USD
# Maximum Salary: 412000 USD
# Salary Range: 409141 USD
#
# Data Specialist:
# Average Salary: 165000.0 USD
# Minimum Salary: 165000 USD
# Maximum Salary: 165000 USD
# Salary Range: 0 USD
#
# Director of Data Engineering:
# Average Salary: 156738.0 USD
# Minimum Salary: 113476 USD
# Maximum Salary: 200000 USD
# Salary Range: 86524 USD
#
# Director of Data Science:
# Average Salary: 195074.0 USD
# Minimum Salary: 130026 USD
# Maximum Salary: 325000 USD
# Salary Range: 194974 USD
#
# ETL Developer:
# Average Salary: 54957.0 USD
# Minimum Salary: 54957 USD
# Maximum Salary: 54957 USD
# Salary Range: 0 USD
#
# Finance Data Analyst:
# Average Salary: 61896.0 USD
# Minimum Salary: 61896 USD
# Maximum Salary: 61896 USD
# Salary Range: 0 USD
#
# Financial Data Analyst:
# Average Salary: 275000.0 USD
# Minimum Salary: 100000 USD
# Maximum Salary: 450000 USD
# Salary Range: 350000 USD
#
# Head of Data:
# Average Salary: 160162.6 USD
# Minimum Salary: 32974 USD
# Maximum Salary: 235000 USD
# Salary Range: 202026 USD
#
# Head of Data Science:
# Average Salary: 146718.75 USD
# Minimum Salary: 85000 USD
# Maximum Salary: 224000 USD
# Salary Range: 139000 USD
#
# Head of Machine Learning:
# Average Salary: 79039.0 USD
# Minimum Salary: 79039 USD
# Maximum Salary: 79039 USD
# Salary Range: 0 USD
#
# Lead Data Analyst:
# Average Salary: 92203.0 USD
# Minimum Salary: 19609 USD
# Maximum Salary: 170000 USD
# Salary Range: 150391 USD
#
# Lead Data Engineer:
# Average Salary: 139724.5 USD
# Minimum Salary: 56000 USD
# Maximum Salary: 276000 USD
# Salary Range: 220000 USD
#
# Lead Data Scientist:
# Average Salary: 115190.0 USD
# Minimum Salary: 40570 USD
# Maximum Salary: 190000 USD
# Salary Range: 149430 USD
#
# Lead Machine Learning Engineer:
# Average Salary: 87932.0 USD
# Minimum Salary: 87932 USD
# Maximum Salary: 87932 USD
# Salary Range: 0 USD
#
# ML Engineer:
# Average Salary: 117504.0 USD
# Minimum Salary: 15966 USD
# Maximum Salary: 270000 USD
# Salary Range: 254034 USD
#
# Machine Learning Developer:
# Average Salary: 85860.67 USD
# Minimum Salary: 78791 USD
# Maximum Salary: 100000 USD
# Salary Range: 21209 USD
#
# Machine Learning Engineer:
# Average Salary: 104880.15 USD
# Minimum Salary: 20000 USD
# Maximum Salary: 250000 USD
# Salary Range: 230000 USD
#
# Machine Learning Infrastructure Engineer:
# Average Salary: 101145.0 USD
# Minimum Salary: 50180 USD
# Maximum Salary: 195000 USD
# Salary Range: 144820 USD
#
# Machine Learning Manager:
# Average Salary: 117104.0 USD
# Minimum Salary: 117104 USD
# Maximum Salary: 117104 USD
# Salary Range: 0 USD
#
# Machine Learning Scientist:
# Average Salary: 158412.5 USD
# Minimum Salary: 12000 USD
# Maximum Salary: 260000 USD
# Salary Range: 248000 USD
#
# Marketing Data Analyst:
# Average Salary: 88654.0 USD
# Minimum Salary: 88654 USD
# Maximum Salary: 88654 USD
# Salary Range: 0 USD
#
# NLP Engineer:
# Average Salary: 37236.0 USD
# Minimum Salary: 37236 USD
# Maximum Salary: 37236 USD
# Salary Range: 0 USD
#
# Principal Data Analyst:
# Average Salary: 122500.0 USD
# Minimum Salary: 75000 USD
# Maximum Salary: 170000 USD
# Salary Range: 95000 USD
#
# Principal Data Engineer:
# Average Salary: 328333.33 USD
# Minimum Salary: 185000 USD
# Maximum Salary: 600000 USD
# Salary Range: 415000 USD
#
# Principal Data Scientist:
# Average Salary: 215242.43 USD
# Minimum Salary: 148261 USD
# Maximum Salary: 416000 USD
# Salary Range: 267739 USD
#
# Product Data Analyst:
# Average Salary: 13036.0 USD
# Minimum Salary: 6072 USD
# Maximum Salary: 20000 USD
# Salary Range: 13928 USD
#
# Research Scientist:
# Average Salary: 109019.5 USD
# Minimum Salary: 42000 USD
# Maximum Salary: 450000 USD
# Salary Range: 408000 USD
#
# Staff Data Scientist:
# Average Salary: 105000.0 USD
# Minimum Salary: 105000 USD
# Maximum Salary: 105000 USD
# Salary Range: 0 USD

# %%
countrystats = {}
averages = []
maxes = []

#read in data
temp = df.groupby(['company_location'])
for x in range(len(company_locations)): 
    country = company_locations[x]
    a = temp.get_group(country)
    tempsalaries = a.salary_in_usd.values.tolist()
    tempavg = round(sum(tempsalaries)/len(tempsalaries),2)
    averages.append(tempavg)
    tempmin = min(tempsalaries)
    tempmax = max(tempsalaries)
    maxes.append(tempmax)
    temprange = tempmax - tempmin
    templist = [tempavg, tempmin, tempmax, temprange]
    countrystats[country] = templist

#output data (by country)
def stats_by_country():
    for key in countrystats: 
        print(key + ":")
        stats = countrystats[key]
        print("Average Salary: " + str(stats[0]) + " USD")
        print("Minimum Salary: " + str(stats[1]) + " USD")
        print("Maximum Salary: " + str(stats[2]) + " USD")
        print("Salary Range: " + str(stats[3]) + " USD")
        print("")

def plot_average():
    #average salary by job title 
    fig = plt.figure(figsize = (30,10))
    plt.bar(company_locations, averages, color = '#87bdd6', width = 0.7)
    plt.xlabel("Countries", fontsize = 20)
    plt.ylabel("Average Salaries", fontsize = 20)
    plt.title("Average Salary by Country (Company Location)", fontsize = 30)
    plt.xticks(rotation=90)
    plt.show

def plot_maximum():
    #maximum salary by job title 

    fig = plt.figure(figsize = (30,10))
    plt.bar(company_locations, maxes, color = '#b688cf', width = 0.7)
    plt.xlabel("Countries", fontsize = 20)
    plt.ylabel("Maximum Salaries", fontsize = 20)
    plt.title("Maximum Salary by Country (Company Location)", fontsize = 30)
    plt.xticks(rotation=90)
    plt.show

stats_by_country()
plot_average()
plot_maximum()
# Out:
# DE:
# Average Salary: 81887.21 USD
# Minimum Salary: 15966 USD
# Maximum Salary: 173762 USD
# Salary Range: 157796 USD
#
# JP:
# Average Salary: 114127.33 USD
# Minimum Salary: 41689 USD
# Maximum Salary: 260000 USD
# Salary Range: 218311 USD
#
# GB:
# Average Salary: 81583.04 USD
# Minimum Salary: 37300 USD
# Maximum Salary: 183228 USD
# Salary Range: 145928 USD
#
# HN:
# Average Salary: 20000.0 USD
# Minimum Salary: 20000 USD
# Maximum Salary: 20000 USD
# Salary Range: 0 USD
#
# US:
# Average Salary: 144055.26 USD
# Minimum Salary: 5679 USD
# Maximum Salary: 600000 USD
# Salary Range: 594321 USD
#
# HU:
# Average Salary: 35735.0 USD
# Minimum Salary: 35735 USD
# Maximum Salary: 35735 USD
# Salary Range: 0 USD
#
# NZ:
# Average Salary: 125000.0 USD
# Minimum Salary: 125000 USD
# Maximum Salary: 125000 USD
# Salary Range: 0 USD
#
# FR:
# Average Salary: 63970.67 USD
# Minimum Salary: 36643 USD
# Maximum Salary: 152000 USD
# Salary Range: 115357 USD
#
# IN:
# Average Salary: 28581.75 USD
# Minimum Salary: 5409 USD
# Maximum Salary: 94665 USD
# Salary Range: 89256 USD
#
# PK:
# Average Salary: 13333.33 USD
# Minimum Salary: 8000 USD
# Maximum Salary: 20000 USD
# Salary Range: 12000 USD
#
# CN:
# Average Salary: 71665.5 USD
# Minimum Salary: 43331 USD
# Maximum Salary: 100000 USD
# Salary Range: 56669 USD
#
# GR:
# Average Salary: 52293.09 USD
# Minimum Salary: 20000 USD
# Maximum Salary: 87932 USD
# Salary Range: 67932 USD
#
# AE:
# Average Salary: 100000.0 USD
# Minimum Salary: 65000 USD
# Maximum Salary: 120000 USD
# Salary Range: 55000 USD
#
# NL:
# Average Salary: 54945.75 USD
# Minimum Salary: 42000 USD
# Maximum Salary: 69741 USD
# Salary Range: 27741 USD
#
# MX:
# Average Salary: 32123.33 USD
# Minimum Salary: 2859 USD
# Maximum Salary: 60000 USD
# Salary Range: 57141 USD
#
# CA:
# Average Salary: 99823.73 USD
# Minimum Salary: 52000 USD
# Maximum Salary: 225000 USD
# Salary Range: 173000 USD
#
# AT:
# Average Salary: 72920.75 USD
# Minimum Salary: 61467 USD
# Maximum Salary: 91237 USD
# Salary Range: 29770 USD
#
# NG:
# Average Salary: 30000.0 USD
# Minimum Salary: 10000 USD
# Maximum Salary: 50000 USD
# Salary Range: 40000 USD
#
# ES:
# Average Salary: 53060.14 USD
# Minimum Salary: 10354 USD
# Maximum Salary: 87932 USD
# Salary Range: 77578 USD
#
# PT:
# Average Salary: 47793.75 USD
# Minimum Salary: 21983 USD
# Maximum Salary: 60757 USD
# Salary Range: 38774 USD
#
# DK:
# Average Salary: 54386.33 USD
# Minimum Salary: 28609 USD
# Maximum Salary: 88654 USD
# Salary Range: 60045 USD
#
# IT:
# Average Salary: 36366.5 USD
# Minimum Salary: 21669 USD
# Maximum Salary: 51064 USD
# Salary Range: 29395 USD
#
# HR:
# Average Salary: 45618.0 USD
# Minimum Salary: 45618 USD
# Maximum Salary: 45618 USD
# Salary Range: 0 USD
#
# LU:
# Average Salary: 43942.67 USD
# Minimum Salary: 10000 USD
# Maximum Salary: 62726 USD
# Salary Range: 52726 USD
#
# PL:
# Average Salary: 66082.5 USD
# Minimum Salary: 28476 USD
# Maximum Salary: 153667 USD
# Salary Range: 125191 USD
#
# SG:
# Average Salary: 89294.0 USD
# Minimum Salary: 89294 USD
# Maximum Salary: 89294 USD
# Salary Range: 0 USD
#
# RO:
# Average Salary: 60000.0 USD
# Minimum Salary: 60000 USD
# Maximum Salary: 60000 USD
# Salary Range: 0 USD
#
# IQ:
# Average Salary: 100000.0 USD
# Minimum Salary: 100000 USD
# Maximum Salary: 100000 USD
# Salary Range: 0 USD
#
# BR:
# Average Salary: 18602.67 USD
# Minimum Salary: 12901 USD
# Maximum Salary: 24000 USD
# Salary Range: 11099 USD
#
# BE:
# Average Salary: 85699.0 USD
# Minimum Salary: 82744 USD
# Maximum Salary: 88654 USD
# Salary Range: 5910 USD
#
# UA:
# Average Salary: 13400.0 USD
# Minimum Salary: 13400 USD
# Maximum Salary: 13400 USD
# Salary Range: 0 USD
#
# IL:
# Average Salary: 119059.0 USD
# Minimum Salary: 119059 USD
# Maximum Salary: 119059 USD
# Salary Range: 0 USD
#
# RU:
# Average Salary: 157500.0 USD
# Minimum Salary: 85000 USD
# Maximum Salary: 230000 USD
# Salary Range: 145000 USD
#
# MT:
# Average Salary: 28369.0 USD
# Minimum Salary: 28369 USD
# Maximum Salary: 28369 USD
# Salary Range: 0 USD
#
# CL:
# Average Salary: 40038.0 USD
# Minimum Salary: 40038 USD
# Maximum Salary: 40038 USD
# Salary Range: 0 USD
#
# IR:
# Average Salary: 4000.0 USD
# Minimum Salary: 4000 USD
# Maximum Salary: 4000 USD
# Salary Range: 0 USD
#
# CO:
# Average Salary: 21844.0 USD
# Minimum Salary: 21844 USD
# Maximum Salary: 21844 USD
# Salary Range: 0 USD
#
# MD:
# Average Salary: 18000.0 USD
# Minimum Salary: 18000 USD
# Maximum Salary: 18000 USD
# Salary Range: 0 USD
#
# KE:
# Average Salary: 9272.0 USD
# Minimum Salary: 9272 USD
# Maximum Salary: 9272 USD
# Salary Range: 0 USD
#
# SI:
# Average Salary: 63831.0 USD
# Minimum Salary: 24823 USD
# Maximum Salary: 102839 USD
# Salary Range: 78016 USD
#
# CH:
# Average Salary: 64114.0 USD
# Minimum Salary: 5882 USD
# Maximum Salary: 122346 USD
# Salary Range: 116464 USD
#
# VN:
# Average Salary: 4000.0 USD
# Minimum Salary: 4000 USD
# Maximum Salary: 4000 USD
# Salary Range: 0 USD
#
# AS:
# Average Salary: 18053.0 USD
# Minimum Salary: 18053 USD
# Maximum Salary: 18053 USD
# Salary Range: 0 USD
#
# TR:
# Average Salary: 20096.67 USD
# Minimum Salary: 12103 USD
# Maximum Salary: 28016 USD
# Salary Range: 15913 USD
#
# CZ:
# Average Salary: 50937.0 USD
# Minimum Salary: 31875 USD
# Maximum Salary: 69999 USD
# Salary Range: 38124 USD
#
# DZ:
# Average Salary: 100000.0 USD
# Minimum Salary: 100000 USD
# Maximum Salary: 100000 USD
# Salary Range: 0 USD
#
# EE:
# Average Salary: 32974.0 USD
# Minimum Salary: 32974 USD
# Maximum Salary: 32974 USD
# Salary Range: 0 USD
#
# MY:
# Average Salary: 40000.0 USD
# Minimum Salary: 40000 USD
# Maximum Salary: 40000 USD
# Salary Range: 0 USD
#
# AU:
# Average Salary: 108042.67 USD
# Minimum Salary: 86703 USD
# Maximum Salary: 150000 USD
# Salary Range: 63297 USD
#
# IE:
# Average Salary: 71444.0 USD
# Minimum Salary: 71444 USD
# Maximum Salary: 71444 USD
# Salary Range: 0 USD

# %%
#general plotting to visualise clusters
#seaborn practice

seaborn.pairplot(df)
plt.show()

seaborn.pairplot(df,hue="experience_level")
plt.show()

seaborn.relplot(data=df, x ="company_location", y="salary_in_usd", hue="experience_level")
plt.show()

# %%
#replace non-numerical with numerical data
from cgi import test


X = df[['job_title']]
y = df['salary_in_usd']

testdf = df.copy()
mappings = {}
def LabelEncode(df):
    columnsToEncode = ["experience_level", "employment_type","employee_residence","company_location","company_size"]
    le = LabelEncoder()
    for feature in columnsToEncode: 
        df[feature] = le.fit_transform(df[feature])
        le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
        mappings[feature] = le_name_mapping
    return df

LabelEncode(testdf)

#prints how the labels map to the original non-numeric labels

def PrintMappings():
    for mapping in mappings: 
        print(mapping + ":")
        print(mappings[mapping])
        print('')

PrintMappings()
# Out:
# experience_level:
# {'EN': 0, 'EX': 1, 'MI': 2, 'SE': 3}
#
# employment_type:
# {'CT': 0, 'FL': 1, 'FT': 2, 'PT': 3}
#
# employee_residence:
# {'AE': 0, 'AR': 1, 'AT': 2, 'AU': 3, 'BE': 4, 'BG': 5, 'BO': 6, 'BR': 7, 'CA': 8, 'CH': 9, 'CL': 10, 'CN': 11, 'CO': 12, 'CZ': 13, 'DE': 14, 'DK': 15, 'DZ': 16, 'EE': 17, 'ES': 18, 'FR': 19, 'GB': 20, 'GR': 21, 'HK': 22, 'HN': 23, 'HR': 24, 'HU': 25, 'IE': 26, 'IN': 27, 'IQ': 28, 'IR': 29, 'IT': 30, 'JE': 31, 'JP': 32, 'KE': 33, 'LU': 34, 'MD': 35, 'MT': 36, 'MX': 37, 'MY': 38, 'NG': 39, 'NL': 40, 'NZ': 41, 'PH': 42, 'PK': 43, 'PL': 44, 'PR': 45, 'PT': 46, 'RO': 47, 'RS': 48, 'RU': 49, 'SG': 50, 'SI': 51, 'TN': 52, 'TR': 53, 'UA': 54, 'US': 55, 'VN': 56}
#
# company_location:
# {'AE': 0, 'AS': 1, 'AT': 2, 'AU': 3, 'BE': 4, 'BR': 5, 'CA': 6, 'CH': 7, 'CL': 8, 'CN': 9, 'CO': 10, 'CZ': 11, 'DE': 12, 'DK': 13, 'DZ': 14, 'EE': 15, 'ES': 16, 'FR': 17, 'GB': 18, 'GR': 19, 'HN': 20, 'HR': 21, 'HU': 22, 'IE': 23, 'IL': 24, 'IN': 25, 'IQ': 26, 'IR': 27, 'IT': 28, 'JP': 29, 'KE': 30, 'LU': 31, 'MD': 32, 'MT': 33, 'MX': 34, 'MY': 35, 'NG': 36, 'NL': 37, 'NZ': 38, 'PK': 39, 'PL': 40, 'PT': 41, 'RO': 42, 'RU': 43, 'SG': 44, 'SI': 45, 'TR': 46, 'UA': 47, 'US': 48, 'VN': 49}
#
# company_size:
# {'L': 0, 'M': 1, 'S': 2}

# %%
X = testdf.company_location.tolist()
y = testdf.salary_in_usd.tolist()
print(X)
print(y)

regr = linear_model.LinearRegression()
regr.fit(X,y)
tester = regr.predict([[0]])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#normal linear regression: experience against salary
X = testdf[['experience_level']]
y = testdf[['salary_in_usd']]
X_train, X_test, y_train, y_test = train_test_split(X,y,shuffle=True,train_size=0.3)
model = LinearRegression()
model.fit(X_train.to_numpy(), y_train.to_numpy())
print("COEFFICIENT: "+ str(model.coef_))
print("INTERCEPT: " + str(model.intercept_))

def MakePrediction():
    param = 0
    value = input("Input what level of experience to predict salaries for: (EN/MI/EX/SE)")
    if value == "EN":
        param = 0
    elif value == "MI":
        param = 2
    elif value == "EX":
        param = 1
    elif value == "SE":
        param = 3
    print(param)
    prediction = model.predict([[param]])
    return(prediction)

a = MakePrediction()
print(a)
# Out:
# COEFFICIENT: [[17838.26912263]]
# INTERCEPT: [78390.584128]
# 3
# [[131905.3914959]]

# %%
#multivariate linear regression: experience against salary
Xmulti = testdf[['experience_level','company_location']]
ymulti = testdf['salary_in_usd']
X_trainm, X_testm, y_trainm, y_testm = train_test_split(Xmulti,ymulti,shuffle=True,train_size=0.3)
modelmulti = LinearRegression()
modelmulti.fit(X_trainm.to_numpy(), y_trainm.to_numpy())
print("COEFFICIENT: "+ str(modelmulti.coef_))
print("INTERCEPT: " + str(modelmulti.intercept_))

modelmulti.predict([[0,48]])
# Out:
# COEFFICIENT: [20474.22096042  1238.58577968]
# INTERCEPT: 23232.215846575098
# array([82684.33327144])
